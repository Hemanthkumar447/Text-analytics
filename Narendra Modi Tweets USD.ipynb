# %%
import pandas as pd
import numpy as np
import nltk

# %%
tweets = pd.read_csv('https://raw.githubusercontent.com/skathirmani/datasets/master/narendramodi_tweets.csv')

# %%
tweets.head(10)
# Out:
#              id  retweets_count  favorite_count           created_at  \
# 0  8.263846e+17          1406.0          4903.0  2017-01-31 11:00:07
# 1  8.263843e+17           907.0          2877.0  2017-01-31 10:59:12
# 2  8.263827e+17           694.0             0.0  2017-01-31 10:52:33
# 3  8.263826e+17           666.0             0.0  2017-01-31 10:52:22
# 4  8.263826e+17           716.0             0.0  2017-01-31 10:52:16
# 5  8.263826e+17           659.0             0.0  2017-01-31 10:52:09
# 6  8.263824e+17           498.0             0.0  2017-01-31 10:51:25
# 7  8.263823e+17           508.0             0.0  2017-01-31 10:51:18
# 8  8.263823e+17           460.0             0.0  2017-01-31 10:51:08
# 9  8.263822e+17           389.0             0.0  2017-01-31 10:50:55
#
#                                                 text lang  retweeted  \
# 0  The President's address wonderfully encapsulat...   en      False
# 1  Rashtrapati Ji's address to both Houses of Par...   en      False
# 2  RT @PMOIndia: Empowering the marginalised. htt...   en      False
# 3  RT @PMOIndia: Commitment to welfare of farmers...   en      False
# 4  RT @PMOIndia: Improving the quality of life fo...   en      False
# 5  RT @PMOIndia: Financial inclusion for poverty ...   en      False
# 6  RT @RashtrapatiBhvn: The four-decade old deman...   en      False
# 7  RT @RashtrapatiBhvn: My Government has taken b...   en      False
# 8  RT @RashtrapatiBhvn: Under its proactive "Act ...   en      False
# 9  RT @RashtrapatiBhvn: Through Stand-up India in...   en      False
#
#    followers_count  friends_count  hashtags_count              description  \
# 0       26809964.0         1641.0             1.0  Prime Minister of India
# 1       26809964.0         1641.0             0.0  Prime Minister of India
# 2       26809964.0         1641.0             0.0  Prime Minister of India
# 3       26809964.0         1641.0             0.0  Prime Minister of India
# 4       26809964.0         1641.0             0.0  Prime Minister of India
# 5       26809964.0         1641.0             0.0  Prime Minister of India
# 6       26809964.0         1641.0             0.0  Prime Minister of India
# 7       26809964.0         1641.0             1.0  Prime Minister of India
# 8       26809964.0         1641.0             0.0  Prime Minister of India
# 9       26809964.0         1641.0             0.0  Prime Minister of India
#
#   location                               background_image_url  \
# 0    India  http://pbs.twimg.com/profile_background_images...
# 1    India  http://pbs.twimg.com/profile_background_images...
# 2    India  http://pbs.twimg.com/profile_background_images...
# 3    India  http://pbs.twimg.com/profile_background_images...
# 4    India  http://pbs.twimg.com/profile_background_images...
# 5    India  http://pbs.twimg.com/profile_background_images...
# 6    India  http://pbs.twimg.com/profile_background_images...
# 7    India  http://pbs.twimg.com/profile_background_images...
# 8    India  http://pbs.twimg.com/profile_background_images...
# 9    India  http://pbs.twimg.com/profile_background_images...
#
#                source
# 0  Twitter Web Client
# 1  Twitter Web Client
# 2  Twitter Web Client
# 3  Twitter Web Client
# 4  Twitter Web Client
# 5  Twitter Web Client
# 6  Twitter Web Client
# 7  Twitter Web Client
# 8  Twitter Web Client
# 9  Twitter Web Client

# %% [markdown]
# ### 1. Find out the maximum and minimum date from the created_at column

# %%
max_date = tweets['created_at'].max()
max_date
# Out:
# '2017-01-31 11:00:07'

# %%
min_date = tweets['created_at'].min()
min_date
# Out:
# '2016-03-09 12:22:10'

# %% [markdown]
# ### 2. Create word cloud using all the rows for the text column

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

input_string = ' '.join(tweets['text'])
wc = WordCloud(background_color = "Black").generate(input_string)
plt.imshow(wc)

# %% [markdown]
# # 3. Clean the text column by converting all characters into lower case

# %%
docs = tweets['text'].str.lower().str.replace('[^a-z ]', '')
docs.head(10)
# Out:
# 0    the presidents address wonderfully encapsulate...
# 1    rashtrapati jis address to both houses of parl...
# 2    rt pmoindia empowering the marginalised httpst...
# 3    rt pmoindia commitment to welfare of farmers h...
# 4    rt pmoindia improving the quality of life for ...
# 5    rt pmoindia financial inclusion for poverty al...
# 6    rt rashtrapatibhvn the fourdecade old demand o...
# 7    rt rashtrapatibhvn my government has taken bol...
# 8    rt rashtrapatibhvn under its proactive act eas...
# 9    rt rashtrapatibhvn through standup india initi...
# Name: text, dtype: object

# %% [markdown]
# # 4. Remove stopwords

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords[:5]
# Out:
# ['i', 'me', 'my', 'myself', 'we']

# %% [markdown]
# #  5. Apply Stemming

# %%
stemmer = nltk.stem.PorterStemmer()

docs_clean = []
for doc in docs.head(2):
    words = doc.split(' ')
    #print(doc)
    #print(words)
    words_clean =[]
    for word in words:
        if word not in stopwords:
            words_clean.append(stemmer.stem(word))
    
    doc_clean = ' '.join(words_clean)
    docs_clean.append(doc_clean)
    print(docs_clean)
    #print(words_clean)
    print('-------------------------')
# Out:
# ['presid address wonder encapsul india strength aspir potenti amp effort toward transformingindia']
# -------------------------
# ['presid address wonder encapsul india strength aspir potenti amp effort toward transformingindia', 'rashtrapati ji address hous parliament indepth amp extens hear httpstcordkqtjgnnx rashtrapatibhvn']
# -------------------------

# %%
docs=tweets['text'].str.lower().str.replace('[^a-z ]','')

def clean_senetence(text):
    words=text.split(' ')
    words_clean = [stemmer.stem(word) for word in words if word not in stopwords]
    return ' '.join(words_clean)
docs_clean = docs.apply(clean_senetence)
docs_clean.head()
# Out:
# 0    presid address wonder encapsul india strength ...
# 1    rashtrapati ji address hous parliament indepth...
# 2        rt pmoindia empow marginalis httpstcowwsqgwdk
# 3    rt pmoindia commit welfar farmer httpstcopaafr...
# 4    rt pmoindia improv qualiti life poor httpstcou...
# Name: text, dtype: object

# %% [markdown]
# # 6. Create DTM using Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=5)
vectorizer.fit(docs_clean)
dtm = vectorizer.transform(docs_clean)
dtm
# Out:
# <3220x1229 sparse matrix of type '<class 'numpy.int64'>'
# 	with 24767 stored elements in Compressed Sparse Row format>

# %%
no_of_zeros = (3220 * 1229) - 24767
sparsity = (no_of_zeros) / (3220 * 1229) * 100
sparsity
# Out:
# 99.37415663898842

# %%
df_dtm = pd.DataFrame(dtm.toarray(),
                     columns = vectorizer.get_feature_names())
(df_dtm == 0).sum().sum()
# Out:
# 3932613

# %%
(3220 * 1229) - 3932613
# Out:
# 24767

# %% [markdown]
# # 7. Fit the models and find the accuracy_score

# %%
from sklearn.model_selection import train_test_split
train_x, test_x = train_test_split(df_dtm, 
                               test_size = 0.2,
                              random_state = 100)

# %%
train_y = tweets.iloc[train_x.index]['retweeted']
test_y = tweets.iloc[test_x.index]['retweeted']

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state = 100, n_estimators = 300)
model.fit(train_x,train_y)

test_pred = model.predict(test_x)

df_pred = pd.DataFrame({'actual' : test_y,
                       'predicted' : test_pred})


df_pred['pred_status'] = df_pred['actual'] == df_pred['predicted']


df_pred[df_pred['pred_status']==True].shape[0] / df_pred.shape[0] *100
# Out:
# 100.0

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state = 100)
model.fit(train_x,train_y)

test_pred = model.predict(test_x)

df_pred = pd.DataFrame({'actual' : test_y,
                       'predicted' : test_pred})


df_pred['pred_status'] = df_pred['actual'] == df_pred['predicted']


df_pred[df_pred['pred_status']==True].shape[0] / df_pred.shape[0] *100
# Out:
# 100.0

# %%
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(random_state = 100)
model.fit(train_x,train_y)

test_pred = model.predict(test_x)

df_pred = pd.DataFrame({'actual' : test_y,
                       'predicted' : test_pred})


df_pred['pred_status'] = df_pred['actual'] == df_pred['predicted']


df_pred[df_pred['pred_status']==True].shape[0] / df_pred.shape[0] *100
# Out:
# 100.0

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(train_x,train_y)

test_pred = model.predict(test_x)

df_pred = pd.DataFrame({'actual' : test_y,
                       'predicted' : test_pred})


df_pred['pred_status'] = df_pred['actual'] == df_pred['predicted']


df_pred[df_pred['pred_status']==True].shape[0] / df_pred.shape[0] *100
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:461: RuntimeWarning: divide by zero encountered in log
#   self.class_log_prior_ = (np.log(self.class_count_) -
# 100.0

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(train_x,train_y)

test_pred = model.predict(test_x)

df_pred = pd.DataFrame({'actual' : test_y,
                       'predicted' : test_pred})


df_pred['pred_status'] = df_pred['actual'] == df_pred['predicted']


df_pred[df_pred['pred_status']==True].shape[0] / df_pred.shape[0] *100
# Out:
# 100.0

# %% [markdown]
# # 8. Create word cloud for each group using K-Means Clustering

# %%
from sklearn.cluster import KMeans

km_model = KMeans(n_clusters=4)
km_model.fit(df_dtm)
labels = km_model.predict(df_dtm)
len(labels)
# Out:
# 3220

# %%
words_clean_wc = docs
tweets_df = pd.DataFrame({'text':words_clean_wc,'cluster':labels})
tweets_df.head()
# Out:
#    cluster                                               text
# 0        2  the presidents address wonderfully encapsulate...
# 1        2  rashtrapati jis address to both houses of parl...
# 2        3  rt pmoindia empowering the marginalised httpst...
# 3        3  rt pmoindia commitment to welfare of farmers h...
# 4        3  rt pmoindia improving the quality of life for ...

# %%
input_string1 = ' '.join(tweets_df[tweets_df['cluster']==0]['text'])
plt.figure(figsize=(15,10))
wc_cluster1 = WordCloud(background_color='white').generate(input_string1)
plt.imshow(wc_cluster1)

# %%
input_string2 = ' '.join(tweets_df[tweets_df['cluster']==1]['text'])
plt.figure(figsize=(15,10))
wc_cluster2 = WordCloud(background_color='black').generate(input_string2)
plt.imshow(wc_cluster2)

# %%
input_string3 = ' '.join(tweets_df[tweets_df['cluster']==2]['text'])
plt.figure(figsize=(15,10))
wc_cluster3 = WordCloud(background_color='skyblue').generate(input_string3)
plt.imshow(wc_cluster3)

# %%
input_string4= ' '.join(tweets_df[tweets_df['cluster']==3]['text'])
plt.figure(figsize=(15,10))
wc_cluster4 = WordCloud(background_color='grey').generate(input_string4)
plt.imshow(wc_cluster4)
